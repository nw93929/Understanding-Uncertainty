# %% [markdown]
# # Assignment 4
# ### Do three of four.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns

# %% [markdown]
# ### Exercise 1: Contingent Comparisons
# - Load the Minnesota use of force data.
# - Bootstrap the proportion of missing values for `subject_injury` for each race, and plot the results with grouped KDE and ECDF plots
# - Describe what you see. When we consider second order uncertainty, how similar or different are the sampling distributions of these proportions?

# %%
minnesota_data = pd.read_csv('data/mn_police_use_of_force.csv',
                             parse_dates=['response_datetime'])

races = minnesota_data['race'].dropna().unique().tolist()

# Remove the "Pacific Islander" category if it exists in the race list since not enough variability/observations
if "Pacific Islander" in races:
    races.remove("Pacific Islander")

# Define a function to bootstrap the proportion of missing values in subject_injury for race group
def bootstrap_missing(df, race, n_boot=5000):
    race_subset = df[df['race'] == race]
    n = len(race_subset)
    props = []
    
    for _ in range(n_boot):
        sample = race_subset.sample(n, replace=True)
        props.append(sample['subject_injury'].isna().mean()) # calculate proportion missing in the sample
    
    return np.array(props) 

boot_results = {race: bootstrap_missing(minnesota_data, race) for race in races}

# ---------- KDE Plot ----------
plt.figure(figsize=(10,6))
for race, vals in boot_results.items():
    # Plot kernel density estimate of bootstrap proportions
    sns.kdeplot(vals, label=race, fill=True, alpha=0.5)

plt.title("Bootstrap KDE of Missing `subject_injury` Proportion by Race")
plt.xlabel("Proportion Missing")
plt.ylabel("Density")
plt.legend()
plt.show()

# ---------- ECDF Plot ----------
plt.figure(figsize=(10,6))
for race, vals in boot_results.items():
    # Plot empirical cumulative distribution function of proportions
    sns.ecdfplot(vals, label=race)

plt.title("Bootstrap ECDF of Missing `subject_injury` Proportion by Race")
plt.xlabel("Proportion Missing")
plt.ylabel("Cumulative Probability")
plt.legend()
plt.show()

# %% [markdown]
# From the KDE and ECDF plots we see that there does seem to be significant differences in the sampling distribution for each race's proportion missing. Some distributions are very bell shaped, others are extremely steep and peak rapidly and don't have much horizontal width. Their means appear to be located differently as well. This reflects our second order uncertainty (uncertainty about our uncertainty) aka our sampling distributions of possibilities.

# %% [markdown]
# ### Exercise 2: Invitation to Inference
# - Run the simulation code line by line and comment what each line is doing, or write your own code to do the resampling
# - Open the NHANES or Ames prices or College Completion data
# - Use the above function `simulate` to get a sample of estimates for your statistic and your data
# - Create a new function, `interval(L,H,estimates)`, that computes the $L$-th and $H$-th quantiles for your estimates, $H>L$
# - If $L=.05$ and $H=.95$, this is a **90-percent confidence interval**: "For our statistic, this interval captures the true value of the population parameter 90 percent of the time. (We are 90% **confident** that it includes the true value of the parameter, but the probability that the true parameter lies in this interval is 0 or 1.)"
# - We will spend much more time on this later in class, but for people who have done hypothesis testing before, you now know how to do it directly from the data: No central limit theorem required.

# %%
# Load the Ames housing prices dataset
ames_prices_data = pd.read_csv('data/ames_prices.csv', low_memory=False)

col = "price"

# Extract the price column (make sure the column name matches your CSV)
prices = ames_prices_data[col].dropna().values

# Define a function to bootstrap a statistic
def bootstrap(data, statistic_fn, n_boot=5000):
    # Calculate the number of data points
    n = len(data)

    # List to store bootstrap estimates
    estimates = []

    # Perform bootstrap sampling
    for _ in range(n_boot):
        # Resample with replacement
        sample = np.random.choice(data, size=n, replace=True)
        # Compute the statistic on the resample
        estimates.append(statistic_fn(sample))

    return np.array(estimates) # return as a NumPy array

# Function to compute confidence interval
def interval(L, H, estimates):
    return (np.quantile(estimates, L), np.quantile(estimates, H)) # return quartile interval as a tuple

# Bootstrap the mean price
boot_means = bootstrap(prices, np.mean, n_boot=5000)

# 90% confidence interval
ci_90 = interval(0.05, 0.95, boot_means)
print("90% Confidence Interval:", ci_90, "for the target statistic:", "mean", col)

plt.figure(figsize=(10,6))
sns.histplot(boot_means, bins=50, kde=True)
plt.title("Bootstrap Distribution of Mean `price`")
plt.xlabel("Proportion")
plt.ylabel("Frequency")
plt.show()
# Out:
# 90% Confidence Interval: (np.float64(178380.65402730377), np.float64(183219.0192320819)) for the target statistic: mean price

# %% [markdown]
# ### Exercise 3: Intro to A/B Testing
# - Go here, and read about this study: https://www.clinicaltrials.gov/study/NCT01985360
# - Read the Study Overview and explain what the goal of the trial is
# - Read the Study Plan and explain how it was designed and why -- there's lots of medical jargon, but the main point is how patients were assigned to interventions.
# - Read the Results Posted: Go to **Outcome Measures**. Explain how table 1 ("Incidence of Death from Any Cause or Myocardial Infarction") is a contingency table. These are the data for this exercise.
# - What is the difference in surival rates between the invasive strategy and the conservative strategy?
# - Bootstrap the survival rates for the two groups, and plot them as KDEs and ECDFs against one another
# - Bootstrap the difference in surival rates, and plot it as a KDE and ECDF
# - Is this an effective health intervention? Explain your answer clearly
#
# This would be what CS people call **A/B testing** and everyone else called a **randomized controlled trial**: Using randomized assignment to detect the difference in outcomes between two groups. (We've just done a non-parametric version of a two-sample t-test.)

# %% [markdown]
# The trial aims to see if the invasive strategy leads to a longer predicted survivor time for advanced CKD patients than the conservative strategy. The groups were randomly assigned to a treatment, with the number of patients being 388 for invasive and 389 for conservative. Random assignment was used because this allows the statistical conclusions of the study to be valid since the grouping was random. The ultimate goal of this study plan was to test if going aggressive initially produces better results than starting conservative. Table 1 is a contingency table because it shows the number of people with bad outcomes vs good outcomes contingent upon the treatment they recieved, leaving the table with two groups and two outcomes. The difference in survival rates between the invasive and conservative approaches is about 1.5%, with invasive having a slightly higher survival rate at around 68%. To understand if this difference is statistically significant, hypothesis testing must be conducted on the data, but since the confidence intervals are so wide and both contain both estimated survival rates, it is likely not statistically significant.

# %%
# Create a DataFrame of clinical trials data
data = {
    "Arm/Group Description": ["Invasive Strategy", "Conservative Strategy"],
    "Overall Number of Participants Analyzed": [388, 389],
    "Measure Type: Count of Participants": [123, 129]
}

df = pd.DataFrame(data)

# Extract values from df
n_invasive = df.loc[df["Arm/Group Description"] == "Invasive Strategy", 
                    "Overall Number of Participants Analyzed"].values[0]
events_invasive = df.loc[df["Arm/Group Description"] == "Invasive Strategy", 
                         "Measure Type: Count of Participants"].values[0]

n_conservative = df.loc[df["Arm/Group Description"] == "Conservative Strategy", 
                        "Overall Number of Participants Analyzed"].values[0]
events_conservative = df.loc[df["Arm/Group Description"] == "Conservative Strategy", 
                             "Measure Type: Count of Participants"].values[0]

# Survival indicators: 1 = survived, 0 = event
surv_invasive = np.array([1] * (n_invasive - events_invasive) + [0] * events_invasive)
surv_conservative = np.array([1] * (n_conservative - events_conservative) + [0] * events_conservative)

# Bootstrap resampling
n_boot = 10000
boot_invasive = np.random.choice(surv_invasive, (n_boot, n_invasive), replace=True).mean(axis=1)
boot_conservative = np.random.choice(surv_conservative, (n_boot, n_conservative), replace=True).mean(axis=1)

# %%
# KDE Plot
plt.figure(figsize=(10,5))
sns.kdeplot(boot_invasive, label="Invasive Strategy", fill=True)
sns.kdeplot(boot_conservative, label="Conservative Strategy", fill=True)
plt.title("Bootstrap Survival Rate Distributions (KDE)")
plt.xlabel("Survival Rate")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# ECDF Plot
plt.figure(figsize=(10,5))
sns.ecdfplot(boot_invasive, label="Invasive Strategy")
sns.ecdfplot(boot_conservative, label="Conservative Strategy")
plt.title("Bootstrap Survival Rate Distributions (ECDF)")
plt.xlabel("Survival Rate")
plt.ylabel("ECDF")
plt.legend()
plt.show()

# %%
# Bootstrap difference in survival rates
boot_diff = boot_invasive - boot_conservative

# KDE Plot for difference
plt.figure(figsize=(10,5))
sns.kdeplot(boot_diff, fill=True, color="purple")
plt.axvline(0, color="black", linestyle="--", label="No Difference")
plt.title("Bootstrap Difference in Survival Rates (Invasive - Conservative)")
plt.xlabel("Difference in Survival Rate")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# ECDF Plot for difference
plt.figure(figsize=(10,5))
sns.ecdfplot(boot_diff, color="purple")
plt.axvline(0, color="black", linestyle="--", label="No Difference")
plt.title("Bootstrap Difference in Survival Rates (Invasive - Conservative)")
plt.xlabel("Difference in Survival Rate")
plt.ylabel("ECDF")
plt.legend() 
plt.show()

# %% [markdown]
# The distribution of bootstrapped differences is centered very close to **0**, with values spreading both above and below 0. The KDE peak is only slightly shifted to the right of 0, which suggests the invasive strategy might have a very small survival advantage — but the overlap is large. Because the distribution clearly crosses 0, the **95% confidence interval** for the difference almost certainly includes 0. This means there is **no statistically clear evidence** that the invasive strategy improves survival compared to the conservative strategy. The intervention does not produce a consistently higher survival rate; the apparent differences could easily be due to chance.
#
# **Conclusion:** Based on these results, the invasive strategy is *not* an effective health intervention in terms of survival benefit compared to the conservative strategy. At best, any effect is very small and uncertain — not enough to justify the additional risks, costs, and burdens of an invasive approach.

# %% [markdown]
# ### Exercise 4: Prediction Uncertainty
# - Pick a dataset and two continuous variables.
# - Recall the LCLS estimator:
# $$
# \hat{y}(z) =  \frac{ \frac{1}{N} \sum_{i=1}^N y_i \times \frac{1}{h}k\left( \frac{z - x_i}{h} \right)}{ \frac{1}{N} \sum_{i=1}^N \frac{1}{h} k\left( \frac{z - x_i}{h} \right)}
# $$
# with the Epanechnikov kernel and the standard plug-in bandwidth for $h$
# - Compute and plot this line for 30 bootstrap samples. Notice where there is a lot of variation in the predictions, versus little variation in the predictions.
# - Now, for any $z$, we can bootstrap a distribution of predictions using the above formula. Do this at the 25th percentile, median, and 75th percentile of $X$, and make KDE plots of your results.
# - Now, pick a grid for $z$: Obvious choices are all of the unique values in the data, or an equally spaced grid from the minimum value to the maximum value. For each $z$, bootstrap a sample of predictions and compute the .05 and .95 quantiles. Plot these error curves along with your LCLS estimate. Where are your predictions "tight"/reliable? Where are they highly variable/unreliable?
